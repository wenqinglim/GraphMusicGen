# %%
model_dir = 'models/POP8_4'

# %% [markdown]
# Plot losses:

# %%
from plots import plot_losses

# %%
# Uncomment the losses that have to be plotted
losses = [
    # 'tot',
    # 'structure',
    'pitch',
    'dur',
    'reconstruction',
    # 'kld',
    # 'beta*kld'
]
plot_losses(model_dir, losses, plot_val=True)

# %%
# Uncomment the losses that have to be plotted
losses = [
    # 'tot',
    # 'structure',
    # 'pitch',
    # 'dur',
    # 'reconstruction',
    'kld',
    'beta*kld'
]
plot_losses(model_dir, losses, plot_val=True)

# %%
# Uncomment the losses that have to be plotted
losses = [
    # 'tot',
    'structure',
    # 'pitch',
    # 'dur',
    # 'reconstruction',
    # 'kld',
    # 'beta*kld'
]
plot_losses(model_dir, losses, plot_val=True)

# %%
# Uncomment the losses that have to be plotted
losses = [
    'tot',
    # 'structure',
    # 'pitch',
    # 'dur',
    # 'reconstruction',
    # 'kld',
    # 'beta*kld'
]
plot_losses(model_dir, losses, plot_val=True)

# %% [markdown]
# Plot accuracies:

# %%
from plots import plot_accuracies

# %%
# Uncomment the accuracies that have to be plotted
accuracies = [
    # 's_acc',
    # 's_precision',
    # 's_recall',
    # 's_f1',
    'pitch',
    # 'pitch_drums',
    # 'pitch_non_drums',
    'dur',
    'note'
]
plot_accuracies(model_dir, accuracies, plot_val=True)

# %%
# Uncomment the accuracies that have to be plotted
accuracies = [
    's_acc',
    's_precision',
    's_recall',
    's_f1',
    # 'pitch',
    # 'pitch_drums',
    # 'pitch_non_drums',
    # 'dur',
    # 'note'
]
plot_accuracies(model_dir, accuracies, plot_val=False)
